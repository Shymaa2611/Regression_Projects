# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('D:\\MachineCourse\\MachineLearnig\\NLP\\NLP-main\\testCode\\LinearRegressionModels\\quikr_car.csv')

# %%
data.head()
# Out:
#                                      name   company  year          Price  \
# 0    Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                 Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2              Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3  Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4        Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
#
#    kms_driven fuel_type
# 0  45,000 kms    Petrol
# 1      40 kms    Diesel
# 2  22,000 kms    Petrol
# 3  28,000 kms    Petrol
# 4  36,000 kms    Diesel

# %%
data.tail()
# Out:
#                           name    company  year     Price  kms_driven  \
# 887                         Ta       Tara  zest  3,10,000         NaN
# 888        Tata Zest XM Diesel       Tata  2018  2,60,000  27,000 kms
# 889         Mahindra Quanto C8   Mahindra  2013  3,90,000  40,000 kms
# 890   Honda Amaze 1.2 E i VTEC      Honda  2014  1,80,000      Petrol
# 891  Chevrolet Sail 1.2 LT ABS  Chevrolet  2014  1,60,000      Petrol
#
#     fuel_type
# 887       NaN
# 888    Diesel
# 889    Diesel
# 890       NaN
# 891       NaN

# %%
data.value_counts()
# Out:
# name                                 company   year  Price      kms_driven  fuel_type
# Mahindra Scorpio S10                 Mahindra  2015  9,00,000   97,200 kms  Diesel       5
# Honda Amaze                          Honda     2015  3,44,999   22,000 kms  Petrol       4
# Mini Cooper S 1.6                    Mini      2013  18,91,111  13,000 kms  Petrol       4
# Honda Amaze                          Honda     2013  2,84,999   46,000 kms  Diesel       4
# Force Motors Force One LX ABS 7 STR  Force     2015  5,80,000   3,200 kms   Diesel       3
#                                                                                         ..
# Hyundai i10 Sportz 1.2               Hyundai   2010  1,68,000   45,872 kms  Petrol       1
#                                                2011  2,20,000   38,000 kms  Petrol       1
# Hyundai i20                          Hyundai   2009  1,99,000   31,000 kms  Petrol       1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 837 entries, 0 to 889
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        837 non-null    object
#  1   company     837 non-null    object
#  2   year        837 non-null    object
#  3   Price       837 non-null    object
#  4   kms_driven  837 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 45.8+ KB

# %%
data.describe().T
# Out:
#            count unique            top freq
# name         837    473     Honda City   13
# company      837     25         Maruti  229
# year         837     21           2015  117
# Price        837    273  Ask For Price   21
# kms_driven   837    256     45,000 kms   30
# fuel_type    837      3         Petrol  440

# %%
data.duplicated().sum()
# Out:
# 94

# %%
data.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
data=data.dropna()

# %%
data
# Out:
#                                        name   company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007         80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014       5,75,000
# ..                                      ...       ...   ...            ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011       2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009       1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009       3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018       2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013       3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# ...

# %%
import seaborn as sns

# %%
data['Price']=data['Price'].str.replace('Ask For Price','')

# %%
data
# Out:
#                                        name   company  year     Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III   Hyundai  2007    80,000
# 1                   Mahindra Jeep CL550 MDI  Mahindra  2006  4,25,000
# 2                Maruti Suzuki Alto 800 Vxi    Maruti  2018
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT   Hyundai  2014  3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi      Ford  2014  5,75,000
# ..                                      ...       ...   ...       ...
# 883              Maruti Suzuki Ritz VXI ABS    Maruti  2011  2,70,000
# 885               Tata Indica V2 DLE BS III      Tata  2009  1,10,000
# 886                    Toyota Corolla Altis    Toyota  2009  3,00,000
# 888                     Tata Zest XM Diesel      Tata  2018  2,60,000
# 889                      Mahindra Quanto C8  Mahindra  2013  3,90,000
#
#        kms_driven fuel_type
# 0      45,000 kms    Petrol
# 1          40 kms    Diesel
# 2      22,000 kms    Petrol
# ...

# %%
data['Price'].dropna()
# Out:
# 0        80,000
# 1      4,25,000
# 2
# 3      3,25,000
# 4      5,75,000
#          ...
# 883    2,70,000
# 885    1,10,000
# 886    3,00,000
# 888    2,60,000
# 889    3,90,000
# Name: Price, Length: 837, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
sns.barplot(x=data['Company'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=data['Ram'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=data['TypeName'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=data['ScreenResolution'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.barplot(x=data['OpSys'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
sns.distplot(data['Inches'])
# Out:
# D:\Anconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Inches', ylabel='Density'>

# %%
sns.barplot(x=data['Gpu'],y=data['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
data
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
count=0
for i in data:
    if count!=2 or count!=10:
        le.fit(data[i])
        data[i]=le.transform(data[i])
    count+=1

# %%
data
# Out:
#       Company  TypeName  Inches  ScreenResolution  Cpu  Ram  Memory  Gpu  \
# 0           1         4       7                23   65    8       4   58
# 1           1         4       7                 1   63    8       2   51
# 2           7         3      14                 8   74    8      16   53
# 3           1         4      13                25   85    1      29    9
# 4           1         4       7                23   67    8      16   59
# ...       ...       ...     ...               ...  ...  ...     ...  ...
# 1298       10         0      10                13   89    5       4   47
# 1299       10         0       7                19   89    1      29   47
# 1300       10         3      10                 0   34    3      35   40
# 1301        7         3      14                 0   89    7      10   21
# 1302        2         3      14                 0   34    5      26   40
#
#       OpSys  Weight  Price
# 0         8      38    524
# 1         8      35    342
# ...

# %%
data.corr()['Price']
# Out:
# Company             0.153080
# TypeName           -0.127454
# Inches             -0.064207
# ScreenResolution    0.389303
# Cpu                 0.609172
# Ram                -0.167915
# Memory              0.155570
# Gpu                 0.455556
# OpSys               0.331114
# Weight             -0.045706
# Price               1.000000
# Name: Price, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
drop_data=['TypeName','Inches','Weight']
data=data.drop(columns=drop_data,axis=1)

# %%
data
# Out:
#       Company  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys  Price
# 0           1                23   65    8       4   58      8    524
# 1           1                 1   63    8       2   51      8    342
# 2           7                 8   74    8      16   53      4    168
# 3           1                25   85    1      29    9      8    745
# 4           1                23   67    8      16   59      8    637
# ...       ...               ...  ...  ...     ...  ...    ...    ...
# 1298       10                13   89    5       4   47      5    200
# 1299       10                19   89    1      29   47      5    575
# 1300       10                 0   34    3      35   40      5      8
# 1301        7                 0   89    7      10   21      5    265
# 1302        2                 0   34    5      26   40      5     67
#
# [1303 rows x 8 columns]

# %%
X=data.iloc[:,:-1]

# %%
y=data['Price']

# %%
X
# Out:
#       Company  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys
# 0           1                23   65    8       4   58      8
# 1           1                 1   63    8       2   51      8
# 2           7                 8   74    8      16   53      4
# 3           1                25   85    1      29    9      8
# 4           1                23   67    8      16   59      8
# ...       ...               ...  ...  ...     ...  ...    ...
# 1298       10                13   89    5       4   47      5
# 1299       10                19   89    1      29   47      5
# 1300       10                 0   34    3      35   40      5
# 1301        7                 0   89    7      10   21      5
# 1302        2                 0   34    5      26   40      5
#
# [1303 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=44)

# %%
X_train
# Out:
#       Company  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys
# 478         4                 8   83    8      10    6      5
# 1066        2                15   93    6      12   92      5
# 562         7                19   47    1      29   46      5
# 503        10                 0   37    5      26   43      5
# 266         2                 7  106    8      34   61      5
# ...       ...               ...  ...  ...     ...  ...    ...
# 84          0                 0   14    5      10   17      5
# 96          4                 8   97    8      10   24      2
# 571         7                 0  112    8      22   42      5
# 1197        2                15   92    1      31   93      5
# 753        10                 8   68    5       9   47      5
#
# [912 rows x 7 columns]

# %%
X_test
# Out:
#       Company  ScreenResolution  Cpu  Ram  Memory  Gpu  OpSys
# 494         2                13   92    2      18   90      5
# 1275        2                15   45    8      29   46      5
# 715        10                15   74    8      16   66      5
# 772        16                 9   68    5       4   47      5
# 1206        7                 0   74    8      16   53      5
# ...       ...               ...  ...  ...     ...  ...    ...
# 496        10                 8  106    8      16   61      5
# 376        10                 9   41    5       4   43      5
# 882         2                 0   37    5      23   43      5
# 255         4                 8   83    8      16   61      5
# 883        10                15   89    8      10   72      5
#
# [391 rows x 7 columns]

# %%
y_train
# Out:
# 478     219
# 1066    786
# 562     676
# 503      38
# 266     575
#        ...
# 84       78
# 96      184
# 571      74
# 1197    705
# 753     429
# Name: Price, Length: 912, dtype: int64

# %%
y_test
# Out:
# 494     500
# 1275    247
# 715     321
# 772     396
# 1206    170
#        ...
# 496     341
# 376     158
# 882      57
# 255     365
# 883     218
# Name: Price, Length: 391, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neural_network import MLPRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import Pipeline

# %%
model=RandomForestRegressor()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
model.n_estimators
# Out:
# 100

# %%
y_pred=model.predict(X_test)

# %%
y_pred
# Out:
# array([537.32      , 271.06      , 393.91833333, 431.9325    ,
#        381.63066667, 488.83552381, 280.52      , 391.05816667,
#        293.71      , 420.985     , 445.2225    , 545.385     ,
#        131.22083333, 260.88121429, 659.99333333, 643.34      ,
#        463.583     , 516.08171429, 422.66933333, 717.84375   ,
#        563.15159524, 527.66      , 437.32      , 477.8655    ,
#        254.28      ,  72.27      , 145.45416667, 475.6       ,
#         59.17      , 628.56      , 128.35      , 375.77333333,
#        388.7702381 , 658.2       , 668.1755    , 713.49333333,
#        461.42321429, 455.17595238, 535.55583333, 532.15      ,
#        656.03216667, 338.24833333, 451.15861905, 157.93      ,
#        212.08833333, 172.945     , 551.93566667, 112.31916667,
#        663.10619048, 360.65565476, 309.46716667, 424.03829762,
#        486.2627381 ,  76.01      , 718.6105    , 707.87      ,
#         88.91      , 181.21916667, 453.158     , 161.18866667,
# ...

# %%
from sklearn.metrics import mean_absolute_error,r2_score

# %%
error=mean_absolute_error(y_test,y_pred)

# %%
error
# Out:
# 65.64927986378498

# %%
model.score(X_train,y_train)
# Out:
# 0.9633202501912018

# %%
model.score(X_test,y_test)
# Out:
# 0.8351734050931322

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8351734050931322
